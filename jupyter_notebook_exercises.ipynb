# %% [markdown]
# Markdown tak można sobie pisać tekst.
#
# * lol
# * lol
#
# * **shift + enter** żeby uruchomić działąnia na tekście
# * kwiazdka plus spacja robi się bullet list
#
# # Heading
# ## Heading
# ### Heading
#
# **bold**
#
# *example*
#
# https://www.google.pl/
#
# https://www.youtube.com/
#
# umiem też renderować LaTex

# %%
# %matplotlib inline
from matplotlib.pyplot import plot

plot([0,1,0,1,2])

# %% [markdown]
# * **esc + strzałki** to poruszanie się po boxach
# * jeśli chcemy wystartować plot na górze **shift + run**
